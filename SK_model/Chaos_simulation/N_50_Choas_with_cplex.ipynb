# %%
import numpy as np
import pandas as pd
from docplex.mp.model import Model
import os
# import dimod
# from dwave.system import LeapHybridSampler

# %%
# --- Generate couplings ---
def generate_J(N, seed=None):
    # Create directory if it doesn't exist
    os.makedirs('generated_data', exist_ok=True)
    
    if seed is not None:
        np.random.seed(seed)
    std = 1.0 / np.sqrt(N)
    data = [(i, j, np.random.normal(0, std)) for i in range(N) for j in range(i+1, N)]
    df = pd.DataFrame(data, columns=['i','j','Jij'])
    
    if seed is not None:
        filepath = f'generated_data/Jij_N{N}_seed{seed}.csv'
        df.to_csv(filepath, index=False)
        print(f"Saved couplings for N={N} to {filepath}")
    else:
        filepath = f'generated_data/Jij_N{N}.csv'
        df.to_csv(filepath, index=False)
        print(f"Saved couplings for N={N} to {filepath}")

# --- Generate perturbed couplings (Goal 3) ---
def generate_J_perturbed(N, seed_orig, seed_pert, epsilon=0.01):
    """
    Generate perturbed couplings: J_ij^pert = J_ij^orig + epsilon * delta_J_ij
    where delta_J_ij is independent noise with same distribution as J_ij.
    
    Args:
        N: System size
        seed_orig: Seed for original couplings (must already exist)
        seed_pert: Seed for independent perturbation noise
        epsilon: Perturbation strength (default 0.01)
    """
    os.makedirs('generated_data', exist_ok=True)
    
    # Load original couplings
    df_orig = pd.read_csv(f'generated_data/Jij_N{N}_seed{seed_orig}.csv')
    
    # Generate independent perturbation noise
    np.random.seed(seed_pert)
    std = 1.0 / np.sqrt(N)
    delta_J = [np.random.normal(0, std) for _ in range(len(df_orig))]
    
    # Create perturbed couplings
    df_pert = df_orig.copy()
    df_pert['Jij'] = df_orig['Jij'] + epsilon * np.array(delta_J)
    
    filepath = f'generated_data/Jij_N{N}_seed{seed_orig}_pert{seed_pert}_eps{epsilon}.csv'
    df_pert.to_csv(filepath, index=False)
    print(f"Saved perturbed couplings to {filepath}")
    return df_pert

# --- Load couplings ---
def load_J(N, seed=None, seed_pert=None, epsilon=0.01):
    if seed_pert is not None:
        # Load perturbed couplings
        filename = f'generated_data/Jij_N{N}_seed{seed}_pert{seed_pert}_eps{epsilon}.csv'
    elif seed is not None:
        # Load original couplings
        filename = f'generated_data/Jij_N{N}_seed{seed}.csv'
    else:
        filename = f'generated_data/Jij_N{N}.csv'
    
    df = pd.read_csv(filename)
    N = max(df['i'].max(), df['j'].max()) + 1
    return [(int(i), int(j), float(Jij)) for i,j,Jij in df.values], N

# %%
def solve_SK(rows, N, seed, time_limit=None, perturbed=False, seed_pert=None, epsilon=0.01):
    from docplex.mp.model import Model
    import pandas as pd
    import os
    
    # Create directory if it doesn't exist
    os.makedirs('cplex_solutions', exist_ok=True)

    mdl = Model('SK_Ising')
    x = mdl.binary_var_list(N, name='x')

    expr = 0
    for i, j, Jij in rows:
        expr += -4*Jij * x[i]*x[j] + 2*Jij*(x[i] + x[j]) - Jij

    mdl.minimize(expr)

    if time_limit is not None:
        mdl.parameters.timelimit = float(time_limit)

    sol = mdl.solve(log_output=False)

    if not sol:
        print("No solution found.")
        return

    x_sol = [int(sol.get_value(var)) for var in x]
    S = [2*xi - 1 for xi in x_sol]
    E = sum(-Jij * S[i]*S[j] for i,j,Jij in rows)

    # Print solution status and gap
    status = mdl.solve_details.status
    mip_gap = mdl.solve_details.mip_relative_gap

    print(f"N = {N}\nEnergy = {E}")
    print(f"Status: {status}")
    if mip_gap is not None:
        print(f"MIP gap: {mip_gap:.4f}")

    # Save with appropriate filename
    if perturbed and seed_pert is not None:
        filepath = f'cplex_solutions/solution_N{N}_seed{seed}_pert{seed_pert}_eps{epsilon}.csv'
    else:
        filepath = f'cplex_solutions/solution_N{N}_seed{seed}.csv'
    
    pd.DataFrame({'i': range(N), 'Energy_cplex': E, 'x': x_sol, 'S': S}).to_csv(filepath, index=False)
    print(f"Saved solution to {filepath}")
    return E, S

# %% [markdown]
# ## Goal 3: Chaos Exponent - Original Ground States
#
# First, compute ground states for original (unperturbed) couplings.

# %%
# Goal 3: Compute original ground states (already done above, but rerun if needed)
N = 50
M = 40  # Number of disorder realizations for Goal 3

# Only run if solutions don't exist
energy_orig_list = []
for i in range(M):
    # Check if solution already exists
    filepath = f'cplex_solutions/solution_N{N}_seed{i}.csv'
    if os.path.exists(filepath):
        df = pd.read_csv(filepath)
        E_orig = df['Energy_cplex'][0]
        print(f"Loaded existing solution for seed {i}: E = {E_orig}")
    else:
        # Generate and solve if not exists
        generate_J(N, seed=i)
        rows, N = load_J(N, seed=i)
        E_orig, S_orig = solve_SK(rows, N, seed=i, time_limit=300)
    
    energy_orig_list.append(E_orig)

print(f"\nOriginal energies computed for {M} realizations.")
print(f"Mean E/N = {np.mean(energy_orig_list)/N:.4f}")
# Out:
# Saved couplings for N=50 to generated_data/Jij_N50_seed0.csv
# N = 50
# Energy = -33.952800215526594
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed0.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed1.csv
# N = 50
# Energy = -33.952800215526594
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed0.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed1.csv
# N = 50
# Energy = -36.2219649608972
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed1.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed2.csv
# N = 50
# Energy = -36.2219649608972
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed1.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed2.csv
# N = 50
# Energy = -34.954109670887355
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed2.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed3.csv
# N = 50
# Energy = -34.954109670887355
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed2.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed3.csv
# N = 50
# Energy = -35.93114968316619
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed3.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed4.csv
# N = 50
# Energy = -35.93114968316619
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed3.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed4.csv
# N = 50
# Energy = -34.23939127574053
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed4.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed5.csv
# N = 50
# Energy = -34.23939127574053
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed4.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed5.csv
# N = 50
# Energy = -34.22793362913186
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed5.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed6.csv
# N = 50
# Energy = -34.22793362913186
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed5.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed6.csv
# N = 50
# Energy = -34.80929343261018
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed6.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed7.csv
# N = 50
# Energy = -34.80929343261018
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed6.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed7.csv
# N = 50
# Energy = -34.622787916677
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed7.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed8.csv
# N = 50
# Energy = -34.622787916677
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed7.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed8.csv
# N = 50
# Energy = -36.08815121341452
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed8.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed9.csv
# N = 50
# Energy = -36.08815121341452
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed8.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed9.csv
# N = 50
# Energy = -37.53305304061223
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed9.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed10.csv
# N = 50
# Energy = -37.53305304061223
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed9.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed10.csv
# N = 50
# Energy = -33.18903035485116
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed10.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed11.csv
# N = 50
# Energy = -33.18903035485116
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed10.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed11.csv
# N = 50
# Energy = -34.54220402531446
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed11.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed12.csv
# N = 50
# Energy = -34.54220402531446
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed11.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed12.csv
# N = 50
# Energy = -35.630250828521355
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed12.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed13.csv
# N = 50
# Energy = -35.630250828521355
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed12.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed13.csv
# N = 50
# Energy = -34.44808190463297
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed13.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed14.csv
# N = 50
# Energy = -34.44808190463297
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed13.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed14.csv
# N = 50
# Energy = -34.65104420324619
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed14.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed15.csv
# N = 50
# Energy = -34.65104420324619
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed14.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed15.csv
# N = 50
# Energy = -34.91025956536077
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed15.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed16.csv
# N = 50
# Energy = -34.91025956536077
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed15.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed16.csv
# N = 50
# Energy = -35.64595580129003
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed16.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed17.csv
# N = 50
# Energy = -35.64595580129003
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed16.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed17.csv
# N = 50
# Energy = -36.0607822054876
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed17.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed18.csv
# N = 50
# Energy = -36.0607822054876
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed17.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed18.csv
# N = 50
# Energy = -35.76963846481879
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed18.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed19.csv
# N = 50
# Energy = -35.76963846481879
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed18.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed19.csv
# N = 50
# Energy = -34.98474037394506
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed19.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed20.csv
# N = 50
# Energy = -34.98474037394506
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed19.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed20.csv
# N = 50
# Energy = -35.14212950695982
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed20.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed21.csv
# N = 50
# Energy = -35.14212950695982
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed20.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed21.csv
# N = 50
# Energy = -37.42273209822919
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed21.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed22.csv
# N = 50
# Energy = -37.42273209822919
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed21.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed22.csv
# N = 50
# Energy = -37.307759457690025
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed22.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed23.csv
# N = 50
# Energy = -37.307759457690025
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed22.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed23.csv
# N = 50
# Energy = -36.81772949118754
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed23.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed24.csv
# N = 50
# Energy = -36.81772949118754
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed23.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed24.csv
# N = 50
# Energy = -37.31968011730315
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed24.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed25.csv
# N = 50
# Energy = -37.31968011730315
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed24.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed25.csv
# N = 50
# Energy = -35.90024205885578
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed25.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed26.csv
# N = 50
# Energy = -35.90024205885578
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed25.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed26.csv
# N = 50
# Energy = -35.98024730937028
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed26.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed27.csv
# N = 50
# Energy = -35.98024730937028
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed26.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed27.csv
# N = 50
# Energy = -35.29108800809223
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed27.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed28.csv
# N = 50
# Energy = -35.29108800809223
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed27.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed28.csv
# N = 50
# Energy = -34.34741413520371
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed28.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed29.csv
# N = 50
# Energy = -34.34741413520371
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed28.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed29.csv
# N = 50
# Energy = -37.953514240464784
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed29.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed30.csv
# N = 50
# Energy = -37.953514240464784
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed29.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed30.csv
# N = 50
# Energy = -34.44903477074156
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed30.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed31.csv
# N = 50
# Energy = -34.44903477074156
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed30.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed31.csv
# N = 50
# Energy = -37.507927494262134
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed31.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed32.csv
# N = 50
# Energy = -37.507927494262134
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed31.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed32.csv
# N = 50
# Energy = -34.158065680662375
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed32.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed33.csv
# N = 50
# Energy = -34.158065680662375
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed32.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed33.csv
# N = 50
# Energy = -32.93907075643458
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed33.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed34.csv
# N = 50
# Energy = -32.93907075643458
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed33.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed34.csv
# N = 50
# Energy = -32.49843627375456
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed34.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed35.csv
# N = 50
# Energy = -32.49843627375456
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed34.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed35.csv
# N = 50
# Energy = -36.50884145519201
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed35.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed36.csv
# N = 50
# Energy = -36.50884145519201
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed35.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed36.csv
# N = 50
# Energy = -40.47124182269032
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed36.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed37.csv
# N = 50
# Energy = -40.47124182269032
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed36.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed37.csv
# N = 50
# Energy = -33.741335498154896
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed37.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed38.csv
# N = 50
# Energy = -33.741335498154896
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed37.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed38.csv
# N = 50
# Energy = -34.35485690896416
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed38.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed39.csv
# N = 50
# Energy = -34.35485690896416
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed38.csv
# Saved couplings for N=50 to generated_data/Jij_N50_seed39.csv
# N = 50
# Energy = -36.18730518650341
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed39.csv
#
# Original energies computed for 40 realizations.
# Mean E/N = -0.7094
# N = 50
# Energy = -36.18730518650341
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed39.csv
#
# Original energies computed for 40 realizations.
# Mean E/N = -0.7094

# %% [markdown]
# ## Goal 3: Perturbed Ground States
#
# Generate perturbed couplings and compute ground states: $J_{ij}^{\text{pert}} = J_{ij}^{\text{orig}} + \epsilon \cdot \delta J_{ij}$

# %%
# Goal 3: Compute perturbed ground states
# Option A: M=20 different disorder realizations, each with one independent perturbation
epsilon = 0.01

energy_pert_list = []
delta_E_list = []

for i in range(M):
    # Use different perturbation seed for each disorder (seed_pert = 10000 + i)
    # This ensures independent perturbation noise for each base disorder
    seed_pert = 10000 + i
    
    # Generate perturbed couplings
    generate_J_perturbed(N, seed_orig=i, seed_pert=seed_pert, epsilon=epsilon)
    
    # Load and solve perturbed instance
    rows_pert, N = load_J(N, seed=i, seed_pert=seed_pert, epsilon=epsilon)
    E_pert, S_pert = solve_SK(rows_pert, N, seed=i, time_limit=300, 
                               perturbed=True, seed_pert=seed_pert, epsilon=epsilon)
    
    energy_pert_list.append(E_pert)
    
    # Compute energy change
    E_orig = energy_orig_list[i]
    delta_E = abs(E_pert - E_orig)
    delta_E_list.append(delta_E)
    
    print(f"Seed {i}, Pert {seed_pert}: E_orig = {E_orig:.4f}, E_pert = {E_pert:.4f}, |ΔE| = {delta_E:.4f}")

# Compute RMS energy change (disorder-averaged)
delta_E_rms = np.sqrt(np.mean(np.array(delta_E_list)**2))
print(f"\n--- Goal 3 Results (N={N}, ε={epsilon}) ---")
print(f"RMS energy change: ⟨(ΔE)²⟩^(1/2) = {delta_E_rms:.4f}")
print(f"Mean |ΔE| = {np.mean(delta_E_list):.4f} ± {np.std(delta_E_list):.4f}")
print(f"Standard protocol: {M} disorder realizations, each with independent perturbation")
# Out:
# Saved perturbed couplings to generated_data/Jij_N50_seed0_pert10000_eps0.01.csv
# N = 50
# Energy = -33.99566427486773
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed0_pert10000_eps0.01.csv
# Seed 0, Pert 10000: E_orig = -33.9528, E_pert = -33.9957, |ΔE| = 0.0429
# Saved perturbed couplings to generated_data/Jij_N50_seed1_pert10001_eps0.01.csv
# N = 50
# Energy = -33.99566427486773
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed0_pert10000_eps0.01.csv
# Seed 0, Pert 10000: E_orig = -33.9528, E_pert = -33.9957, |ΔE| = 0.0429
# Saved perturbed couplings to generated_data/Jij_N50_seed1_pert10001_eps0.01.csv
# N = 50
# Energy = -36.216823236041954
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed1_pert10001_eps0.01.csv
# Seed 1, Pert 10001: E_orig = -36.2220, E_pert = -36.2168, |ΔE| = 0.0051
# Saved perturbed couplings to generated_data/Jij_N50_seed2_pert10002_eps0.01.csv
# N = 50
# Energy = -36.216823236041954
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed1_pert10001_eps0.01.csv
# Seed 1, Pert 10001: E_orig = -36.2220, E_pert = -36.2168, |ΔE| = 0.0051
# Saved perturbed couplings to generated_data/Jij_N50_seed2_pert10002_eps0.01.csv
# N = 50
# Energy = -34.919149474563035
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed2_pert10002_eps0.01.csv
# Seed 2, Pert 10002: E_orig = -34.9541, E_pert = -34.9191, |ΔE| = 0.0350
# Saved perturbed couplings to generated_data/Jij_N50_seed3_pert10003_eps0.01.csv
# N = 50
# Energy = -34.919149474563035
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed2_pert10002_eps0.01.csv
# Seed 2, Pert 10002: E_orig = -34.9541, E_pert = -34.9191, |ΔE| = 0.0350
# Saved perturbed couplings to generated_data/Jij_N50_seed3_pert10003_eps0.01.csv
# N = 50
# Energy = -35.96788625429115
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed3_pert10003_eps0.01.csv
# Seed 3, Pert 10003: E_orig = -35.9311, E_pert = -35.9679, |ΔE| = 0.0367
# Saved perturbed couplings to generated_data/Jij_N50_seed4_pert10004_eps0.01.csv
# N = 50
# Energy = -35.96788625429115
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed3_pert10003_eps0.01.csv
# Seed 3, Pert 10003: E_orig = -35.9311, E_pert = -35.9679, |ΔE| = 0.0367
# Saved perturbed couplings to generated_data/Jij_N50_seed4_pert10004_eps0.01.csv
# N = 50
# Energy = -34.25272595184294
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed4_pert10004_eps0.01.csv
# Seed 4, Pert 10004: E_orig = -34.2394, E_pert = -34.2527, |ΔE| = 0.0133
# Saved perturbed couplings to generated_data/Jij_N50_seed5_pert10005_eps0.01.csv
# N = 50
# Energy = -34.25272595184294
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed4_pert10004_eps0.01.csv
# Seed 4, Pert 10004: E_orig = -34.2394, E_pert = -34.2527, |ΔE| = 0.0133
# Saved perturbed couplings to generated_data/Jij_N50_seed5_pert10005_eps0.01.csv
# N = 50
# Energy = -34.21177143844467
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed5_pert10005_eps0.01.csv
# Seed 5, Pert 10005: E_orig = -34.2279, E_pert = -34.2118, |ΔE| = 0.0162
# Saved perturbed couplings to generated_data/Jij_N50_seed6_pert10006_eps0.01.csv
# N = 50
# Energy = -34.21177143844467
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed5_pert10005_eps0.01.csv
# Seed 5, Pert 10005: E_orig = -34.2279, E_pert = -34.2118, |ΔE| = 0.0162
# Saved perturbed couplings to generated_data/Jij_N50_seed6_pert10006_eps0.01.csv
# N = 50
# Energy = -34.71721720930056
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed6_pert10006_eps0.01.csv
# Seed 6, Pert 10006: E_orig = -34.8093, E_pert = -34.7172, |ΔE| = 0.0921
# Saved perturbed couplings to generated_data/Jij_N50_seed7_pert10007_eps0.01.csv
# N = 50
# Energy = -34.71721720930056
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed6_pert10006_eps0.01.csv
# Seed 6, Pert 10006: E_orig = -34.8093, E_pert = -34.7172, |ΔE| = 0.0921
# Saved perturbed couplings to generated_data/Jij_N50_seed7_pert10007_eps0.01.csv
# N = 50
# Energy = -34.65898162406594
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed7_pert10007_eps0.01.csv
# Seed 7, Pert 10007: E_orig = -34.6228, E_pert = -34.6590, |ΔE| = 0.0362
# Saved perturbed couplings to generated_data/Jij_N50_seed8_pert10008_eps0.01.csv
# N = 50
# Energy = -34.65898162406594
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed7_pert10007_eps0.01.csv
# Seed 7, Pert 10007: E_orig = -34.6228, E_pert = -34.6590, |ΔE| = 0.0362
# Saved perturbed couplings to generated_data/Jij_N50_seed8_pert10008_eps0.01.csv
# N = 50
# Energy = -36.05329419830292
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed8_pert10008_eps0.01.csv
# Seed 8, Pert 10008: E_orig = -36.0882, E_pert = -36.0533, |ΔE| = 0.0349
# Saved perturbed couplings to generated_data/Jij_N50_seed9_pert10009_eps0.01.csv
# N = 50
# Energy = -36.05329419830292
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed8_pert10008_eps0.01.csv
# Seed 8, Pert 10008: E_orig = -36.0882, E_pert = -36.0533, |ΔE| = 0.0349
# Saved perturbed couplings to generated_data/Jij_N50_seed9_pert10009_eps0.01.csv
# N = 50
# Energy = -37.571142651444084
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed9_pert10009_eps0.01.csv
# Seed 9, Pert 10009: E_orig = -37.5331, E_pert = -37.5711, |ΔE| = 0.0381
# Saved perturbed couplings to generated_data/Jij_N50_seed10_pert10010_eps0.01.csv
# N = 50
# Energy = -37.571142651444084
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed9_pert10009_eps0.01.csv
# Seed 9, Pert 10009: E_orig = -37.5331, E_pert = -37.5711, |ΔE| = 0.0381
# Saved perturbed couplings to generated_data/Jij_N50_seed10_pert10010_eps0.01.csv
# N = 50
# Energy = -33.2176252917101
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed10_pert10010_eps0.01.csv
# Seed 10, Pert 10010: E_orig = -33.1890, E_pert = -33.2176, |ΔE| = 0.0286
# Saved perturbed couplings to generated_data/Jij_N50_seed11_pert10011_eps0.01.csv
# N = 50
# Energy = -33.2176252917101
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed10_pert10010_eps0.01.csv
# Seed 10, Pert 10010: E_orig = -33.1890, E_pert = -33.2176, |ΔE| = 0.0286
# Saved perturbed couplings to generated_data/Jij_N50_seed11_pert10011_eps0.01.csv
# N = 50
# Energy = -34.5170397607861
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed11_pert10011_eps0.01.csv
# Seed 11, Pert 10011: E_orig = -34.5422, E_pert = -34.5170, |ΔE| = 0.0252
# Saved perturbed couplings to generated_data/Jij_N50_seed12_pert10012_eps0.01.csv
# N = 50
# Energy = -34.5170397607861
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed11_pert10011_eps0.01.csv
# Seed 11, Pert 10011: E_orig = -34.5422, E_pert = -34.5170, |ΔE| = 0.0252
# Saved perturbed couplings to generated_data/Jij_N50_seed12_pert10012_eps0.01.csv
# N = 50
# Energy = -35.66730170092856
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed12_pert10012_eps0.01.csv
# Seed 12, Pert 10012: E_orig = -35.6303, E_pert = -35.6673, |ΔE| = 0.0371
# Saved perturbed couplings to generated_data/Jij_N50_seed13_pert10013_eps0.01.csv
# N = 50
# Energy = -35.66730170092856
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed12_pert10012_eps0.01.csv
# Seed 12, Pert 10012: E_orig = -35.6303, E_pert = -35.6673, |ΔE| = 0.0371
# Saved perturbed couplings to generated_data/Jij_N50_seed13_pert10013_eps0.01.csv
# N = 50
# Energy = -34.40599594641359
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed13_pert10013_eps0.01.csv
# Seed 13, Pert 10013: E_orig = -34.4481, E_pert = -34.4060, |ΔE| = 0.0421
# Saved perturbed couplings to generated_data/Jij_N50_seed14_pert10014_eps0.01.csv
# N = 50
# Energy = -34.40599594641359
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed13_pert10013_eps0.01.csv
# Seed 13, Pert 10013: E_orig = -34.4481, E_pert = -34.4060, |ΔE| = 0.0421
# Saved perturbed couplings to generated_data/Jij_N50_seed14_pert10014_eps0.01.csv
# N = 50
# Energy = -34.699901278679974
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed14_pert10014_eps0.01.csv
# Seed 14, Pert 10014: E_orig = -34.6510, E_pert = -34.6999, |ΔE| = 0.0489
# Saved perturbed couplings to generated_data/Jij_N50_seed15_pert10015_eps0.01.csv
# N = 50
# Energy = -34.699901278679974
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed14_pert10014_eps0.01.csv
# Seed 14, Pert 10014: E_orig = -34.6510, E_pert = -34.6999, |ΔE| = 0.0489
# Saved perturbed couplings to generated_data/Jij_N50_seed15_pert10015_eps0.01.csv
# N = 50
# Energy = -34.81919184082616
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed15_pert10015_eps0.01.csv
# Seed 15, Pert 10015: E_orig = -34.9103, E_pert = -34.8192, |ΔE| = 0.0911
# Saved perturbed couplings to generated_data/Jij_N50_seed16_pert10016_eps0.01.csv
# N = 50
# Energy = -34.81919184082616
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed15_pert10015_eps0.01.csv
# Seed 15, Pert 10015: E_orig = -34.9103, E_pert = -34.8192, |ΔE| = 0.0911
# Saved perturbed couplings to generated_data/Jij_N50_seed16_pert10016_eps0.01.csv
# N = 50
# Energy = -35.616566033561874
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed16_pert10016_eps0.01.csv
# Seed 16, Pert 10016: E_orig = -35.6460, E_pert = -35.6166, |ΔE| = 0.0294
# Saved perturbed couplings to generated_data/Jij_N50_seed17_pert10017_eps0.01.csv
# N = 50
# Energy = -35.616566033561874
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed16_pert10016_eps0.01.csv
# Seed 16, Pert 10016: E_orig = -35.6460, E_pert = -35.6166, |ΔE| = 0.0294
# Saved perturbed couplings to generated_data/Jij_N50_seed17_pert10017_eps0.01.csv
# N = 50
# Energy = -36.0766168417756
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed17_pert10017_eps0.01.csv
# Seed 17, Pert 10017: E_orig = -36.0608, E_pert = -36.0766, |ΔE| = 0.0158
# Saved perturbed couplings to generated_data/Jij_N50_seed18_pert10018_eps0.01.csv
# N = 50
# Energy = -36.0766168417756
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed17_pert10017_eps0.01.csv
# Seed 17, Pert 10017: E_orig = -36.0608, E_pert = -36.0766, |ΔE| = 0.0158
# Saved perturbed couplings to generated_data/Jij_N50_seed18_pert10018_eps0.01.csv
# N = 50
# Energy = -35.793334712840014
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed18_pert10018_eps0.01.csv
# Seed 18, Pert 10018: E_orig = -35.7696, E_pert = -35.7933, |ΔE| = 0.0237
# Saved perturbed couplings to generated_data/Jij_N50_seed19_pert10019_eps0.01.csv
# N = 50
# Energy = -35.793334712840014
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed18_pert10018_eps0.01.csv
# Seed 18, Pert 10018: E_orig = -35.7696, E_pert = -35.7933, |ΔE| = 0.0237
# Saved perturbed couplings to generated_data/Jij_N50_seed19_pert10019_eps0.01.csv
# N = 50
# Energy = -34.87499976410113
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed19_pert10019_eps0.01.csv
# Seed 19, Pert 10019: E_orig = -34.9847, E_pert = -34.8750, |ΔE| = 0.1097
# Saved perturbed couplings to generated_data/Jij_N50_seed20_pert10020_eps0.01.csv
# N = 50
# Energy = -34.87499976410113
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed19_pert10019_eps0.01.csv
# Seed 19, Pert 10019: E_orig = -34.9847, E_pert = -34.8750, |ΔE| = 0.1097
# Saved perturbed couplings to generated_data/Jij_N50_seed20_pert10020_eps0.01.csv
# N = 50
# Energy = -35.16089851107464
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed20_pert10020_eps0.01.csv
# Seed 20, Pert 10020: E_orig = -35.1421, E_pert = -35.1609, |ΔE| = 0.0188
# Saved perturbed couplings to generated_data/Jij_N50_seed21_pert10021_eps0.01.csv
# N = 50
# Energy = -35.16089851107464
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed20_pert10020_eps0.01.csv
# Seed 20, Pert 10020: E_orig = -35.1421, E_pert = -35.1609, |ΔE| = 0.0188
# Saved perturbed couplings to generated_data/Jij_N50_seed21_pert10021_eps0.01.csv
# N = 50
# Energy = -37.34957562471733
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed21_pert10021_eps0.01.csv
# Seed 21, Pert 10021: E_orig = -37.4227, E_pert = -37.3496, |ΔE| = 0.0732
# Saved perturbed couplings to generated_data/Jij_N50_seed22_pert10022_eps0.01.csv
# N = 50
# Energy = -37.34957562471733
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed21_pert10021_eps0.01.csv
# Seed 21, Pert 10021: E_orig = -37.4227, E_pert = -37.3496, |ΔE| = 0.0732
# Saved perturbed couplings to generated_data/Jij_N50_seed22_pert10022_eps0.01.csv
# N = 50
# Energy = -37.31019224554923
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed22_pert10022_eps0.01.csv
# Seed 22, Pert 10022: E_orig = -37.3078, E_pert = -37.3102, |ΔE| = 0.0024
# Saved perturbed couplings to generated_data/Jij_N50_seed23_pert10023_eps0.01.csv
# N = 50
# Energy = -37.31019224554923
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed22_pert10022_eps0.01.csv
# Seed 22, Pert 10022: E_orig = -37.3078, E_pert = -37.3102, |ΔE| = 0.0024
# Saved perturbed couplings to generated_data/Jij_N50_seed23_pert10023_eps0.01.csv
# N = 50
# Energy = -36.835502432289324
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed23_pert10023_eps0.01.csv
# Seed 23, Pert 10023: E_orig = -36.8177, E_pert = -36.8355, |ΔE| = 0.0178
# Saved perturbed couplings to generated_data/Jij_N50_seed24_pert10024_eps0.01.csv
# N = 50
# Energy = -36.835502432289324
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed23_pert10023_eps0.01.csv
# Seed 23, Pert 10023: E_orig = -36.8177, E_pert = -36.8355, |ΔE| = 0.0178
# Saved perturbed couplings to generated_data/Jij_N50_seed24_pert10024_eps0.01.csv
# N = 50
# Energy = -37.4493377632701
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed24_pert10024_eps0.01.csv
# Seed 24, Pert 10024: E_orig = -37.3197, E_pert = -37.4493, |ΔE| = 0.1297
# Saved perturbed couplings to generated_data/Jij_N50_seed25_pert10025_eps0.01.csv
# N = 50
# Energy = -37.4493377632701
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed24_pert10024_eps0.01.csv
# Seed 24, Pert 10024: E_orig = -37.3197, E_pert = -37.4493, |ΔE| = 0.1297
# Saved perturbed couplings to generated_data/Jij_N50_seed25_pert10025_eps0.01.csv
# N = 50
# Energy = -35.93611009852475
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed25_pert10025_eps0.01.csv
# Seed 25, Pert 10025: E_orig = -35.9002, E_pert = -35.9361, |ΔE| = 0.0359
# Saved perturbed couplings to generated_data/Jij_N50_seed26_pert10026_eps0.01.csv
# N = 50
# Energy = -35.93611009852475
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed25_pert10025_eps0.01.csv
# Seed 25, Pert 10025: E_orig = -35.9002, E_pert = -35.9361, |ΔE| = 0.0359
# Saved perturbed couplings to generated_data/Jij_N50_seed26_pert10026_eps0.01.csv
# N = 50
# Energy = -36.004815695348725
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed26_pert10026_eps0.01.csv
# Seed 26, Pert 10026: E_orig = -35.9802, E_pert = -36.0048, |ΔE| = 0.0246
# Saved perturbed couplings to generated_data/Jij_N50_seed27_pert10027_eps0.01.csv
# N = 50
# Energy = -36.004815695348725
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed26_pert10026_eps0.01.csv
# Seed 26, Pert 10026: E_orig = -35.9802, E_pert = -36.0048, |ΔE| = 0.0246
# Saved perturbed couplings to generated_data/Jij_N50_seed27_pert10027_eps0.01.csv
# N = 50
# Energy = -35.287269374341214
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed27_pert10027_eps0.01.csv
# Seed 27, Pert 10027: E_orig = -35.2911, E_pert = -35.2873, |ΔE| = 0.0038
# Saved perturbed couplings to generated_data/Jij_N50_seed28_pert10028_eps0.01.csv
# N = 50
# Energy = -35.287269374341214
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed27_pert10027_eps0.01.csv
# Seed 27, Pert 10027: E_orig = -35.2911, E_pert = -35.2873, |ΔE| = 0.0038
# Saved perturbed couplings to generated_data/Jij_N50_seed28_pert10028_eps0.01.csv
# N = 50
# Energy = -34.37196225021093
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed28_pert10028_eps0.01.csv
# Seed 28, Pert 10028: E_orig = -34.3474, E_pert = -34.3720, |ΔE| = 0.0245
# Saved perturbed couplings to generated_data/Jij_N50_seed29_pert10029_eps0.01.csv
# N = 50
# Energy = -34.37196225021093
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed28_pert10028_eps0.01.csv
# Seed 28, Pert 10028: E_orig = -34.3474, E_pert = -34.3720, |ΔE| = 0.0245
# Saved perturbed couplings to generated_data/Jij_N50_seed29_pert10029_eps0.01.csv
# N = 50
# Energy = -37.92831191387066
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed29_pert10029_eps0.01.csv
# Seed 29, Pert 10029: E_orig = -37.9535, E_pert = -37.9283, |ΔE| = 0.0252
# Saved perturbed couplings to generated_data/Jij_N50_seed30_pert10030_eps0.01.csv
# N = 50
# Energy = -37.92831191387066
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed29_pert10029_eps0.01.csv
# Seed 29, Pert 10029: E_orig = -37.9535, E_pert = -37.9283, |ΔE| = 0.0252
# Saved perturbed couplings to generated_data/Jij_N50_seed30_pert10030_eps0.01.csv
# N = 50
# Energy = -34.416837553646346
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed30_pert10030_eps0.01.csv
# Seed 30, Pert 10030: E_orig = -34.4490, E_pert = -34.4168, |ΔE| = 0.0322
# Saved perturbed couplings to generated_data/Jij_N50_seed31_pert10031_eps0.01.csv
# N = 50
# Energy = -34.416837553646346
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed30_pert10030_eps0.01.csv
# Seed 30, Pert 10030: E_orig = -34.4490, E_pert = -34.4168, |ΔE| = 0.0322
# Saved perturbed couplings to generated_data/Jij_N50_seed31_pert10031_eps0.01.csv
# N = 50
# Energy = -37.497127287373516
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed31_pert10031_eps0.01.csv
# Seed 31, Pert 10031: E_orig = -37.5079, E_pert = -37.4971, |ΔE| = 0.0108
# Saved perturbed couplings to generated_data/Jij_N50_seed32_pert10032_eps0.01.csv
# N = 50
# Energy = -37.497127287373516
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed31_pert10031_eps0.01.csv
# Seed 31, Pert 10031: E_orig = -37.5079, E_pert = -37.4971, |ΔE| = 0.0108
# Saved perturbed couplings to generated_data/Jij_N50_seed32_pert10032_eps0.01.csv
# N = 50
# Energy = -34.1620259603014
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed32_pert10032_eps0.01.csv
# Seed 32, Pert 10032: E_orig = -34.1581, E_pert = -34.1620, |ΔE| = 0.0040
# Saved perturbed couplings to generated_data/Jij_N50_seed33_pert10033_eps0.01.csv
# N = 50
# Energy = -34.1620259603014
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed32_pert10032_eps0.01.csv
# Seed 32, Pert 10032: E_orig = -34.1581, E_pert = -34.1620, |ΔE| = 0.0040
# Saved perturbed couplings to generated_data/Jij_N50_seed33_pert10033_eps0.01.csv
# N = 50
# Energy = -32.96122435996396
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed33_pert10033_eps0.01.csv
# Seed 33, Pert 10033: E_orig = -32.9391, E_pert = -32.9612, |ΔE| = 0.0222
# Saved perturbed couplings to generated_data/Jij_N50_seed34_pert10034_eps0.01.csv
# N = 50
# Energy = -32.96122435996396
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed33_pert10033_eps0.01.csv
# Seed 33, Pert 10033: E_orig = -32.9391, E_pert = -32.9612, |ΔE| = 0.0222
# Saved perturbed couplings to generated_data/Jij_N50_seed34_pert10034_eps0.01.csv
# N = 50
# Energy = -32.48660311060342
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed34_pert10034_eps0.01.csv
# Seed 34, Pert 10034: E_orig = -32.4984, E_pert = -32.4866, |ΔE| = 0.0118
# Saved perturbed couplings to generated_data/Jij_N50_seed35_pert10035_eps0.01.csv
# N = 50
# Energy = -32.48660311060342
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed34_pert10034_eps0.01.csv
# Seed 34, Pert 10034: E_orig = -32.4984, E_pert = -32.4866, |ΔE| = 0.0118
# Saved perturbed couplings to generated_data/Jij_N50_seed35_pert10035_eps0.01.csv
# N = 50
# Energy = -36.4628544344207
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed35_pert10035_eps0.01.csv
# Seed 35, Pert 10035: E_orig = -36.5088, E_pert = -36.4629, |ΔE| = 0.0460
# Saved perturbed couplings to generated_data/Jij_N50_seed36_pert10036_eps0.01.csv
# N = 50
# Energy = -36.4628544344207
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed35_pert10035_eps0.01.csv
# Seed 35, Pert 10035: E_orig = -36.5088, E_pert = -36.4629, |ΔE| = 0.0460
# Saved perturbed couplings to generated_data/Jij_N50_seed36_pert10036_eps0.01.csv
# N = 50
# Energy = -40.55371819956985
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed36_pert10036_eps0.01.csv
# Seed 36, Pert 10036: E_orig = -40.4712, E_pert = -40.5537, |ΔE| = 0.0825
# Saved perturbed couplings to generated_data/Jij_N50_seed37_pert10037_eps0.01.csv
# N = 50
# Energy = -40.55371819956985
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed36_pert10036_eps0.01.csv
# Seed 36, Pert 10036: E_orig = -40.4712, E_pert = -40.5537, |ΔE| = 0.0825
# Saved perturbed couplings to generated_data/Jij_N50_seed37_pert10037_eps0.01.csv
# N = 50
# Energy = -33.70356065195546
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed37_pert10037_eps0.01.csv
# Seed 37, Pert 10037: E_orig = -33.7413, E_pert = -33.7036, |ΔE| = 0.0378
# Saved perturbed couplings to generated_data/Jij_N50_seed38_pert10038_eps0.01.csv
# N = 50
# Energy = -33.70356065195546
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed37_pert10037_eps0.01.csv
# Seed 37, Pert 10037: E_orig = -33.7413, E_pert = -33.7036, |ΔE| = 0.0378
# Saved perturbed couplings to generated_data/Jij_N50_seed38_pert10038_eps0.01.csv
# N = 50
# Energy = -34.38098954822565
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed38_pert10038_eps0.01.csv
# Seed 38, Pert 10038: E_orig = -34.3549, E_pert = -34.3810, |ΔE| = 0.0261
# Saved perturbed couplings to generated_data/Jij_N50_seed39_pert10039_eps0.01.csv
# N = 50
# Energy = -34.38098954822565
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed38_pert10038_eps0.01.csv
# Seed 38, Pert 10038: E_orig = -34.3549, E_pert = -34.3810, |ΔE| = 0.0261
# Saved perturbed couplings to generated_data/Jij_N50_seed39_pert10039_eps0.01.csv
# N = 50
# Energy = -36.142920430192746
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed39_pert10039_eps0.01.csv
# Seed 39, Pert 10039: E_orig = -36.1873, E_pert = -36.1429, |ΔE| = 0.0444
#
# --- Goal 3 Results (N=50, ε=0.01) ---
# RMS energy change: ⟨(ΔE)²⟩^(1/2) = 0.0467
# Mean |ΔE| = 0.0369 ± 0.0286
# Standard protocol: 40 disorder realizations, each with independent perturbation
# N = 50
# Energy = -36.142920430192746
# Status: integer optimal, tolerance
# MIP gap: 0.0001
# Saved solution to cplex_solutions/solution_N50_seed39_pert10039_eps0.01.csv
# Seed 39, Pert 10039: E_orig = -36.1873, E_pert = -36.1429, |ΔE| = 0.0444
#
# --- Goal 3 Results (N=50, ε=0.01) ---
# RMS energy change: ⟨(ΔE)²⟩^(1/2) = 0.0467
# Mean |ΔE| = 0.0369 ± 0.0286
# Standard protocol: 40 disorder realizations, each with independent perturbation

# %%
# Save Goal 3 results for chaos exponent analysis
results_df = pd.DataFrame({
    'seed_orig': range(M),
    'seed_pert': [10000 + i for i in range(M)],
    'E_orig': energy_orig_list,
    'E_pert': energy_pert_list,
    'delta_E': delta_E_list
})

os.makedirs('chaos_results', exist_ok=True)
results_df.to_csv(f'chaos_results/chaos_N{N}_eps{epsilon}.csv', index=False)
print(f"\nSaved chaos results to chaos_results/chaos_N{N}_eps{epsilon}.csv")
print(f"Protocol: {M} disorder realizations × 1 perturbation each = {M} samples")
# Out:
# Saved chaos results to chaos_results/chaos_N50_eps0.01.csv
# Protocol: 40 disorder realizations × 1 perturbation each = 40 samples

# %%
# N= [50, 500, 100]
# rms_energy_change = [0.0467, 0.1652, 0.2120]

# %% [markdown]
# ## Test Different Scaling Laws for ⟨(ΔE)²⟩^(1/2)
